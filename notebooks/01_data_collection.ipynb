# %%
import yfinance as yf
import pandas as pd
import os

# %%
#Create data directory if it doesn't exist
os.makedirs('data/raw', exist_ok=True)

# %%
#Set date range
start_date = "2010-01-01"
end_date = "2024-12-31"

#Assets to collect
tickers = {
    "SPY": "S&P 500",
    "BND": "Total Bond Market",
    "GME": "GameStop",
    "AMC": "AMC Entertainment",
    "BTC-USD": "Bitcoin",
    "ETH-USD": "Ethereum"
}

# %%
for ticker, name in tickers.items():
    print(f"Downloading {name} ({ticker})...")
    data = yf.download(ticker, start=start_date, end=end_date)
    data.to_csv(f"data/raw/{ticker}.csv")
    print(f"✅ Saved to data/raw/{ticker}.csv\n")
# Out:
# ...
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# ✅ Saved to data/raw/SPY.csv
#
# ...
# [*********************100%***********************]  1 of 1 completed
# ✅ Saved to data/raw/BND.csv
#
# ...
# [*********************100%***********************]  1 of 1 completed
# ✅ Saved to data/raw/GME.csv
#
# ...
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ✅ Saved to data/raw/AMC.csv
#
# ...
# [*********************100%***********************]  1 of 1 completed
# ✅ Saved to data/raw/BTC-USD.csv
#
# ...
# ✅ Saved to data/raw/ETH-USD.csv

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load one of the assets to find out what it look like
bnd = pd.read_csv("data/raw/BND.csv")

bnd.head()
# Out:
#         Price               Close                High                 Low  \
# 0      Ticker                 BND                 BND                 BND
# 1        Date                 NaN                 NaN                 NaN
# 2  2010-01-04  50.762203216552734   50.79446382998604   50.67187940567369
# 3  2010-01-05   50.91057586669922  50.968639042155715  50.833153377147234
# 4  2010-01-06   50.89125061035156    50.9557718559625   50.77511925944379
#
#                  Open   Volume
# 0                 BND      BND
# 1                 NaN      NaN
# 2   50.71058820397085  1098100
# 3  50.897669657302224   814600
# 4  50.949318746945416   981300

# %%
# droping the first two rows since they are not neccessary
cols = ["Date", "Close", "High", "Low", "Open", "Volume"]
bnd = pd.read_csv("data/raw/BND.csv", skiprows=3, names=cols, parse_dates=["Date"], index_col="Date")

# %%
bnd.head()
# Out:
#                 Close       High        Low       Open   Volume
# Date
# 2010-01-04  50.762203  50.794464  50.671879  50.710588  1098100
# 2010-01-05  50.910576  50.968639  50.833153  50.897670   814600
# 2010-01-06  50.891251  50.955772  50.775119  50.949319   981300
# 2010-01-07  50.852524  50.884784  50.788008  50.788008   661700
# 2010-01-08  50.904133  50.942842  50.813809  50.891227  1270000
